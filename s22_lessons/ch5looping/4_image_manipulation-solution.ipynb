# %%
from PIL import Image               # to load images
from IPython.display import display # to display images
import numpy as np

# %%
image = Image.open('cat.jpg')
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=116x141 at 0x7FA6AC0A97B8>

# %% [markdown]
# ## 2D image manipulation

# %%
#Using numpy to manipulate image as 2D (rows, columns)

image = Image.open('cat.jpg')
pixels_2D = np.array(image)  #convert to 2D list
print(pixels_2D[0][0])  #first pixel color as [r g b]
print(pixels_2D[100][50])  #pixel at row 100, column 50
pixels_2D[10][100] = [255, 0, 0]  #change color of pixel at row 10, column 100 to red
pixels_2D[100][10] = [0, 0, 0]  #black
image = Image.fromarray(pixels_2D)
display(image)
# Out:
# [247 247 247]
# [216  93  16]
# <PIL.Image.Image image mode=RGB size=116x141 at 0x7FA6ABFD9080>

# %%
#set all pixels in first 20 rows to red
image = Image.open('cat.jpg')

pixels_2D = np.array(image)  #convert to 2D list
rows = len(pixels_2D)
cols = len(pixels_2D[0])
#draw black stripe down image in column 10
for r in range(rows):
        pixels_2D[r][10] = [0,0,0]  #reassign pixel rgb to max red of 255
        
image = Image.fromarray(pixels_2D)
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=116x141 at 0x7FA6ABFD9D30>
# <PIL.Image.Image image mode=RGB size=116x141 at 0x7FA6ABFD9E48>

# %%
#set all pixels in first 20 columns to red
image = Image.open('cat.jpg')

pixels_2D = np.array(image)  #convert to 2D list
rows = len(pixels_2D)
cols = len(pixels_2D[0])

for r in range(rows):
    for c in range(20):
        pixels_2D[r][c] = [255,0,0]  #reassign pixel rgb to max red of 255
        
image = Image.fromarray(pixels_2D)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=116x141 at 0x7FA6ABFD1978>

# %%
#set all pixels in first 20 rows to red
image = Image.open('cat.jpg')

pixels_2D = np.array(image)  #convert to 2D list
rows = len(pixels_2D)
cols = len(pixels_2D[0])

for r in range(20):
    for c in range(cols):
        pixels_2D[r][c] = [255,0,0]  #reassign pixel rgb to max red of 255
        
image = Image.fromarray(pixels_2D)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=116x141 at 0x7FA6ABF95F98>

# %%
#set pixels in top half to blue
image = Image.open('cat.jpg')
display(image)

pixels_2D = np.array(image)  #convert to 2D list
rows = len(pixels_2D)
cols = len(pixels_2D[0])

for r in range(rows//2):
    for c in range(cols):
        pixel = pixels_2D[r][c]
        pixels_2D[r][c] = [0,0,255]
        
image = Image.fromarray(pixels_2D)
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=116x141 at 0x7F7C88965E80>
# <PIL.Image.Image image mode=RGB size=116x141 at 0x7F7C88965DD8>

# %%
image = Image.open('cat.jpg')
display(image)

#add green stripe every 10th row
pixels_2D = np.array(image)  #convert to 2D list
rows = len(pixels_2D)
cols = len(pixels_2D[0])

for r in range(0,rows,10):
    for c in range(cols):
        pixels_2D[r][c] = [0,255,0]
        
image = Image.fromarray(pixels_2D)
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=116x141 at 0x7FA7B472A128>
# <PIL.Image.Image image mode=RGB size=116x141 at 0x7FA7B472A2E8>

# %%
image = Image.open('cat.jpg')
pixels_2D = np.array(image)

pixel = pixels_2D[10][50]   #row 10, column 50
print(pixel)  #[r g b]
red = pixel[0]  #get first value in pixel
green = pixel[1]  #get second value in pixel
blue = pixel[2]  #get third value in pixel
print(red)
print(green)
print(blue)
# Out:
# [214 171 136]
# 214
# 171
# 136

# %%
image = Image.open('cat.jpg')
display(image)

#remove red from pixels in first 50 rows
pixels_2D = np.array(image)  #convert to 2D list
rows = len(pixels_2D)
cols = len(pixels_2D[0])

for r in range(50):
    for c in range(cols):
        pixel = pixels_2D[r][c]
        red=0
        green = pixel[1]
        blue = pixel[2]
        pixels_2D[r][c] = [red,green,blue]
        
image = Image.fromarray(pixels_2D)
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=116x141 at 0x7F7C88962860>
# <PIL.Image.Image image mode=RGB size=116x141 at 0x7F7C88962BE0>

# %%
image = Image.new(mode = "RGB", size = (200, 200))
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FA7B472A710>

# %%
#New blank image (set initial color)

image = Image.new(mode = "RGB", size = (200, 200),color = (153, 153, 255))
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FA7B472AA58>

# %%
#New blank image (set initial color)

image = Image.new(mode = "RGB", size = (200, 200),color = (153, 153, 255))
display(image)

pixels_2D = np.array(image)
rows = len(pixels_2D)
cols = len(pixels_2D[0])#first row
#add white stripe every 10th column

for r in range(rows):
    for c in range(0,cols,10):
        pixels_2D[r][c] = [255, 255, 255]


image = Image.fromarray(pixels_2D)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FA6ABF4E5C0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FA6ABF4E4A8>

# %%
image = Image.new(mode = "RGB", size = (200, 200))

#increase amount of red for each row

pixels_2D = np.array(image)  #convert to 2D list
rows = len(pixels_2D)
cols = len(pixels_2D[0])

red=0
green=0
blue=0

for r in range(rows):
    for c in range(cols):
        pixels_2D[r][c] = [red,green,blue]
            
    red += 1  #increase redness with each new row
    
image = Image.fromarray(pixels_2D)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FA6ABF4E630>

# %%
image = Image.new(mode = "RGB", size = (200, 200))

#increase amount of red for each row

pixels_2D = np.array(image)  #convert to 2D list
rows = len(pixels_2D)
cols = len(pixels_2D[0])

red=0
green=0
blue=0

for r in range(rows):
    for c in range(cols):
        pixels_2D[r][c] = [red,green,blue]
        green += 1
    green = 0
    red += 1  #increase redness with each new row
    
image = Image.fromarray(pixels_2D)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FA6ABFD9A58>
